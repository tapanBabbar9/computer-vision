# %%
import os
import pandas as pd
import requests
from PIL import Image
from io import BytesIO

# Directory to store downloaded images
IMAGE_DIR = "images"
if not os.path.exists(IMAGE_DIR):
    os.makedirs(IMAGE_DIR)

# Read the CSV file containing country names and flag URLs
df = pd.read_csv("national_flags.csv")

# Function to download and save images locally
def download_image(url, country_name):
    # Generate local image path based on country name (sanitize name)
    image_path = os.path.join(IMAGE_DIR, f"{country_name}.png")

    # If the image already exists, skip the download
    if os.path.exists(image_path):
        print(f"Image for {country_name} already exists.")
        return

    # Download the image
    try:
        response = requests.get(url)
        response.raise_for_status()  # Check if the request was successful
        img = Image.open(BytesIO(response.content))  # Open image
        img.save(image_path)  # Save image locally
        print(f"Downloaded and saved image for {country_name}")
    except Exception as e:
        print(f"Error downloading image for {country_name}: {e}")

# Loop through the rows of the CSV and download each image
for _, row in df.iterrows():
    country_name = row['Country']
    flag_url = row['Flag Image']
    
    # Sanitize country name (remove brackets, spaces, etc., to make valid filenames)
    sanitized_country_name = country_name.replace(" ", "_").replace("[", "").replace("]", "")
    
    # Download the image
    download_image(flag_url, sanitized_country_name)
# Out:
# Downloaded and saved image for Afghanistan_(Islamic_Republic)b
# Downloaded and saved image for Albania
# Downloaded and saved image for Algeria
# Downloaded and saved image for Andorra
# Downloaded and saved image for Angola
# Downloaded and saved image for Antigua_and_Barbuda
# Downloaded and saved image for Argentina
# Downloaded and saved image for Armenia
# Downloaded and saved image for Australia
# Downloaded and saved image for Austria
# Downloaded and saved image for Azerbaijan
# Downloaded and saved image for The_Bahamas
# Downloaded and saved image for Bahrain
# Downloaded and saved image for Bangladesh
# Downloaded and saved image for Barbados
# Downloaded and saved image for Belarus
# Downloaded and saved image for Belgium
# Downloaded and saved image for Belize
# Downloaded and saved image for Benin
# Downloaded and saved image for Bhutan
# Downloaded and saved image for Bolivia
# Downloaded and saved image for Bosnia_and_Herzegovina
# Downloaded and saved image for Botswana
# Downloaded and saved image for Brazil
# Downloaded and saved image for Brunei
# Downloaded and saved image for Bulgaria
# Downloaded and saved image for Burkina_Faso
# Downloaded and saved image for Burundi
# Downloaded and saved image for Cambodia
# Downloaded and saved image for Cameroon
# Downloaded and saved image for Canada
# Downloaded and saved image for Cape_Verde
# Downloaded and saved image for Central_African_Republic
# Downloaded and saved image for Chad
# Downloaded and saved image for Chile
# Downloaded and saved image for China
# Downloaded and saved image for Colombia
# Downloaded and saved image for Comoros
# Downloaded and saved image for Democratic_Republic_of_the_Congo
# Downloaded and saved image for Republic_of_the_Congo
# Downloaded and saved image for Costa_Rica
# Downloaded and saved image for Croatia
# Downloaded and saved image for Cuba
# Downloaded and saved image for Cyprus
# Downloaded and saved image for Czech_Republic
# Downloaded and saved image for Denmarki
# Downloaded and saved image for Djibouti
# Downloaded and saved image for Dominica
# Downloaded and saved image for Dominican_Republic
# Downloaded and saved image for East_Timor
# Downloaded and saved image for Ecuador
# Downloaded and saved image for Egypt
# Downloaded and saved image for El_Salvador
# Downloaded and saved image for Equatorial_Guinea
# Downloaded and saved image for Eritrea
# Downloaded and saved image for Estonia
# Downloaded and saved image for Eswatini
# Downloaded and saved image for Ethiopia
# Downloaded and saved image for Fiji
# Downloaded and saved image for Finland
# Downloaded and saved image for France
# Downloaded and saved image for Gabon
# Downloaded and saved image for The_Gambia
# Downloaded and saved image for Georgia
# Downloaded and saved image for Germany
# Downloaded and saved image for Ghana
# Downloaded and saved image for Greece
# Downloaded and saved image for Grenada
# Downloaded and saved image for Guatemala
# Downloaded and saved image for Guinea
# Downloaded and saved image for Guinea-Bissau
# Downloaded and saved image for Guyana
# Downloaded and saved image for Haiti
# Downloaded and saved image for Honduras
# Downloaded and saved image for Hungary
# Downloaded and saved image for Iceland
# Downloaded and saved image for India
# Downloaded and saved image for Indonesia
# Downloaded and saved image for Iran
# Downloaded and saved image for Iraq
# Downloaded and saved image for Ireland
# Downloaded and saved image for Israel
# Downloaded and saved image for Italy
# Downloaded and saved image for Ivory_Coast
# Downloaded and saved image for Jamaica
# Downloaded and saved image for Japan
# Downloaded and saved image for Jordan
# Downloaded and saved image for Kazakhstan
# Downloaded and saved image for Kenya
# Downloaded and saved image for Kiribati
# Downloaded and saved image for Kuwait
# Downloaded and saved image for Kyrgyzstan
# Downloaded and saved image for Laos
# Downloaded and saved image for Latvia
# Downloaded and saved image for Lebanon
# Downloaded and saved image for Lesotho
# Downloaded and saved image for Liberia
# Downloaded and saved image for Libya
# Downloaded and saved image for Liechtenstein
# Downloaded and saved image for Lithuania
# Downloaded and saved image for Luxembourg
# Downloaded and saved image for Madagascar
# Downloaded and saved image for Malawi
# Downloaded and saved image for Malaysia
# Downloaded and saved image for Maldives
# Downloaded and saved image for Mali
# Downloaded and saved image for Malta
# Downloaded and saved image for Marshall_Islands
# Downloaded and saved image for Mauritania
# Downloaded and saved image for Mauritius
# Downloaded and saved image for Mexico
# Downloaded and saved image for Micronesia
# Downloaded and saved image for Moldova
# Downloaded and saved image for Monaco
# Downloaded and saved image for Mongolia
# Downloaded and saved image for Montenegro
# Downloaded and saved image for Morocco
# Downloaded and saved image for Mozambique
# Downloaded and saved image for Myanmar
# Downloaded and saved image for Namibia
# Downloaded and saved image for Nauru
# Downloaded and saved image for Nepal
# Downloaded and saved image for Netherlands
# Downloaded and saved image for New_Zealand
# Downloaded and saved image for Nicaragua
# Downloaded and saved image for Niger
# Downloaded and saved image for Nigeria
# Downloaded and saved image for North_Korea
# Downloaded and saved image for North_Macedonia
# Downloaded and saved image for Norway
# Downloaded and saved image for Oman
# Downloaded and saved image for Pakistan
# Downloaded and saved image for Palau
# Downloaded and saved image for Palestine
# Downloaded and saved image for Panama
# Downloaded and saved image for Papua_New_Guinea
# Downloaded and saved image for Paraguay
# Downloaded and saved image for Peru
# Downloaded and saved image for Philippines
# Downloaded and saved image for Poland
# Downloaded and saved image for Portugal
# Downloaded and saved image for Qatar
# Downloaded and saved image for Romania
# Downloaded and saved image for Russia
# Downloaded and saved image for Rwanda
# Downloaded and saved image for Saint_Kitts_and_Nevis
# Downloaded and saved image for Saint_Lucia
# Downloaded and saved image for Saint_Vincent_and_the_Grenadines
# Downloaded and saved image for Samoa
# Downloaded and saved image for San_Marino
# Downloaded and saved image for São_Tomé_and_Príncipe
# Downloaded and saved image for Saudi_Arabia
# Downloaded and saved image for Senegal
# Downloaded and saved image for Serbia
# Downloaded and saved image for Seychelles
# Downloaded and saved image for Sierra_Leone
# Downloaded and saved image for Singapore
# Downloaded and saved image for Slovakia
# Downloaded and saved image for Slovenia
# Downloaded and saved image for Solomon_Islands
# Downloaded and saved image for Somalia
# Downloaded and saved image for South_Africa
# Downloaded and saved image for South_Korea
# Downloaded and saved image for South_Sudan
# Downloaded and saved image for Spain
# Downloaded and saved image for Sri_Lanka
# Downloaded and saved image for Sudan
# Downloaded and saved image for Suriname
# Downloaded and saved image for Sweden
# Downloaded and saved image for Switzerland
# Downloaded and saved image for Syria
# Downloaded and saved image for Tajikistan
# Downloaded and saved image for Tanzania
# Downloaded and saved image for Thailand
# Downloaded and saved image for Tonga
# Downloaded and saved image for Togo
# Downloaded and saved image for Trinidad_and_Tobago
# Downloaded and saved image for Tunisia
# Downloaded and saved image for Turkey
# Downloaded and saved image for Turkmenistan
# Downloaded and saved image for Tuvalu
# Downloaded and saved image for Uganda
# Downloaded and saved image for Ukraine
# Downloaded and saved image for United_Arab_Emirates
# Downloaded and saved image for United_Kingdom
# Downloaded and saved image for United_States
# Downloaded and saved image for Uruguay
# Downloaded and saved image for Uzbekistan
# Downloaded and saved image for Vanuatu
# Downloaded and saved image for Vatican_City
# Downloaded and saved image for Venezuela
# Downloaded and saved image for Vietnam
# Downloaded and saved image for Yemen
# Downloaded and saved image for Zambia
# Downloaded and saved image for Zimbabwe
